# %%
import numpy as np
import pandas as pd
import json

# %%
answers_no_bbox = pd.read_csv('/media/gnort/HDD6/Study/face-analysis-lightning/outputs/answer.csv')
answers_with_bbox = pd.read_csv('/media/gnort/HDD6/Study/face-analysis-lightning/dataset/public_test/bbox/answers.csv')
name_id_mapping = json.load(open('/media/gnort/HDD6/Study/face-analysis-lightning/dataset/public_test/file_name_to_image_id.json'))

# %%
answers_no_bbox['image_id'] = answers_no_bbox['file_name'].apply(lambda x: name_id_mapping[x])
answers_no_bbox.sort_values(by=['image_id'], inplace=True)
answers_no_bbox
# Out:
#            file_name       race     age    emotion  gender   skintone  \
# 59     100147591.jpg  Caucasian  20-30s    Neutral  Female      light
# 1961   100429351.jpg  Mongoloid  20-30s    Neutral    Male      light
# 527    100473997.jpg  Mongoloid  Senior  Happiness    Male  mid-light
# 1378   100868012.jpg  Caucasian  20-30s  Happiness  Female      light
# 1258   101013830.jpg  Mongoloid  Senior  Happiness    Male      light
# ...              ...        ...     ...        ...     ...        ...
# 1078  image_9841.jpg  Caucasian  40-50s  Happiness    Male      light
# 2125  image_9913.jpg  Mongoloid  20-30s  Happiness  Female  mid-light
# 1131  image_9915.jpg  Caucasian  20-30s  Happiness    Male      light
# 2072  image_9935.jpg  Caucasian  20-30s  Happiness  Female      light
# 1887  image_9975.jpg  Mongoloid  20-30s  Happiness  Female      light
#
#         masked  image_id
# 59    unmasked         1
# 1961  unmasked         2
# 527   unmasked         3
# 1378  unmasked         4
# 1258  unmasked         5
# ...        ...       ...
# 1078  unmasked      2180
# 2125  unmasked      2181
# 1131  unmasked      2182
# 2072  unmasked      2183
# 1887  unmasked      2184
#
# [2174 rows x 8 columns]

# %%
df = answers_no_bbox.merge(answers_with_bbox,
                      on='file_name',
                      suffixes=('', '_no_bbox'),
                      how='left')
df = df.dropna(axis=1, how='any', inplace=False)
df = df[['file_name',
         'bbox',
         'image_id',
         'race',
         'age',
         'emotion',
         'gender',
         'skintone',
         'masked']]
df.to_csv("/media/gnort/HDD6/Study/face-analysis-lightning/dataset/public_test/answers/anser.csv", index=False)
