# %%
import numpy as np
import pandas as pd
import json

# %%
# answers_no_bbox = pd.read_csv('/media/gnort/HDD6/Study/face-analysis-lightning/outputs/answer.csv')
# answers_with_bbox = pd.read_csv('/media/gnort/HDD6/Study/face-analysis-lightning/dataset/public_test/bbox/answers.csv')
# name_id_mapping = json.load(open('/media/gnort/HDD6/Study/face-analysis-lightning/dataset/public_test/file_name_to_image_id.json'))

# %%
# answers_no_bbox['image_id'] = answers_no_bbox['file_name'].apply(lambda x: name_id_mapping[x])
# answers_no_bbox.sort_values(by=['image_id'], inplace=True)
# answers_no_bbox

# %%
answer_race_2 = pd.read_csv("/media/gnort/HDD6/Study/face-analysis-lightning/outputs/answer_race_resnet50_focal_2.csv")
answer_1 = pd.read_csv("/media/gnort/HDD6/Study/face-analysis-lightning/dataset/public_test/answers/answer_1.csv")
answer_race_1 = pd.read_csv("/media/gnort/HDD6/Study/face-analysis-lightning/outputs/answer_race_resnet50_focal.csv")

# %%
answer_race_1.iloc[(answer_race_1.iloc[answer_race_2[answer_race_2["race"] == "Negroid"].index]["race"] != "Negroid").index]
# Out:
#            race        file_name
# 32      Negroid     81809493.jpg
# 41      Negroid  image_10481.jpg
# 49    Mongoloid     66899959.jpg
# 70      Negroid     56212495.jpg
# 87      Negroid     88922419.jpg
# ...         ...              ...
# 2099  Mongoloid   image_7915.jpg
# 2104  Caucasian     39670846.jpg
# 2112  Mongoloid     76869617.jpg
# 2131  Caucasian    image_859.jpg
# 2142  Mongoloid     85087693.jpg
#
# [138 rows x 2 columns]

# %%
# Get all nigga index from answer_2
index_2 = (answer_race_2[answer_race_2["race"] == "Negroid"]).index

# iloc index 2 from answer_1
series_1 = answer_race_1.iloc[index_2][["race", "file_name"]]

# find index not nigga in answer_1
index_1 = series_1.where(series_1["race"] != "Negroid")

index_1 = index_1.dropna()

print(index_1[:50])
# Out:
#            race        file_name
# 49    Mongoloid     66899959.jpg
# 143   Caucasian     73343399.jpg
# 179   Caucasian     82580512.jpg
# 215   Caucasian     67087780.jpg
# 238   Caucasian     56225039.jpg
# 273   Caucasian   image_1936.jpg
# 281   Caucasian     84726863.jpg
# 293   Caucasian     63460857.jpg
# 378   Mongoloid     40597096.jpg
# 428   Caucasian     image_52.jpg
# 432   Caucasian    image_828.jpg
# 447   Caucasian     46253307.jpg
# 463   Caucasian     84919766.jpg
# 470   Caucasian     69417373.jpg
# 472   Mongoloid     84240413.jpg
# 500   Mongoloid     65875120.jpg
# 504   Mongoloid     46680480.jpg
# 541   Caucasian     85189537.jpg
# 542   Mongoloid   image_2360.jpg
# 590   Mongoloid     54463155.jpg
# 607   Mongoloid     81965999.jpg
# 612   Caucasian   image_5188.jpg
# 629   Caucasian     82348904.jpg
# 632   Caucasian     10620731.jpg
# 640   Mongoloid     73033068.jpg
# 671   Caucasian     47490009.jpg
# 681   Mongoloid     60480133.jpg
# 695   Caucasian   image_2642.jpg
# 712   Caucasian    image_217.jpg
# 725   Mongoloid     76546781.jpg
# 740   Mongoloid     77867246.jpg
# 802   Caucasian   image_5414.jpg
# 849   Mongoloid     48408288.jpg
# 908   Caucasian   image_3045.jpg
# 921   Caucasian    image_166.jpg
# 928   Mongoloid     92188221.jpg
# 959   Caucasian     46978324.jpg
# 963   Mongoloid   image_3236.jpg
# 996   Caucasian     30577144.jpg
# 1011  Caucasian     84806099.jpg
# 1015  Caucasian     77692049.jpg
# 1022  Caucasian   image_3964.jpg
# 1028  Caucasian   image_3679.jpg
# 1034  Mongoloid     45509738.jpg
# 1048  Mongoloid   image_3395.jpg
# 1086  Mongoloid     48016780.jpg
# 1117  Caucasian     81276269.jpg
# 1161  Caucasian  image_10319.jpg
# 1188  Caucasian     67938053.jpg
# 1200  Caucasian     24846573.jpg

# %%
print(len(answer_race_1["race"]), len(answer_race_2["race"]))

print(answer_race_1["race"] != answer_race_2["race"])
# Out:
# 2174 2174
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 2169    False
# 2170    False
# 2171    False
# 2172    False
# 2173    False
# Name: race, Length: 2174, dtype: bool

# %%
answer_race[answer_race["race"]=="Negroid"].head(50)
# Out:
#         race        file_name
# 32   Negroid     81809493.jpg
# 41   Negroid  image_10481.jpg
# 49   Negroid     66899959.jpg
# 70   Negroid     56212495.jpg
# 87   Negroid     88922419.jpg
# 104  Negroid     61593122.jpg
# 124  Negroid   image_4441.jpg
# 143  Negroid     73343399.jpg
# 150  Negroid     81301628.jpg
# 161  Negroid     96565212.jpg
# 179  Negroid     82580512.jpg
# 183  Negroid   image_1164.jpg
# 200  Negroid     82946869.jpg
# 215  Negroid     67087780.jpg
# 238  Negroid     56225039.jpg
# 272  Negroid     46374193.jpg
# 273  Negroid   image_1936.jpg
# 281  Negroid     84726863.jpg
# 293  Negroid     63460857.jpg
# 350  Negroid     85924962.jpg
# 378  Negroid     40597096.jpg
# 382  Negroid     86178313.jpg
# 428  Negroid     image_52.jpg
# 432  Negroid    image_828.jpg
# 447  Negroid     46253307.jpg
# 453  Negroid     72704661.jpg
# 455  Negroid     99089874.jpg
# 463  Negroid     84919766.jpg
# 470  Negroid     69417373.jpg
# 472  Negroid     84240413.jpg
# 500  Negroid     65875120.jpg
# 504  Negroid     46680480.jpg
# 541  Negroid     85189537.jpg
# 542  Negroid   image_2360.jpg
# 590  Negroid     54463155.jpg
# 607  Negroid     81965999.jpg
# 612  Negroid   image_5188.jpg
# 629  Negroid     82348904.jpg
# 632  Negroid     10620731.jpg
# 640  Negroid     73033068.jpg
# 671  Negroid     47490009.jpg
# 672  Negroid    104047421.jpg
# 681  Negroid     60480133.jpg
# 695  Negroid   image_2642.jpg
# 712  Negroid    image_217.jpg
# 722  Negroid     84462021.jpg
# 725  Negroid     76546781.jpg
# 740  Negroid     77867246.jpg
# 748  Negroid     76343074.jpg
# 802  Negroid   image_5414.jpg

# %%
answer_race_merge = pd.read_csv("/media/gnort/HDD6/Study/face-analysis-lightning/outputs/answer_race_ir50_1.csv")
answer_race_merge
# Out:
#            race       file_name
# 0     Mongoloid    47219004.jpg
# 1     Mongoloid  image_4995.jpg
# 2     Mongoloid    68589273.jpg
# 3     Mongoloid     3000130.jpg
# 4     Mongoloid   image_617.jpg
# ...         ...             ...
# 2169  Mongoloid  image_7884.jpg
# 2170  Mongoloid    71559800.jpg
# 2171  Mongoloid    67359134.jpg
# 2172  Mongoloid    95861632.jpg
# 2173  Mongoloid    78558549.jpg
#
# [2174 rows x 2 columns]

# %%
df = answer_1.merge(answer_race_merge,
                      on='file_name',
                      how='left')

df = df.dropna(axis=1, how='any', inplace=False)
df.drop(columns=['race_x'], inplace=True, axis=1)
df.rename(columns={'race_y':'race'}, inplace=True)
df = df[['file_name',
         'bbox',
         'image_id',
         'race',
         'age',
         'emotion',
         'gender',
         'skintone',
         'masked']]
print(df)
df.to_csv("/media/gnort/HDD6/Study/face-analysis-lightning/dataset/public_test/answers/answer_2.csv", index=False)
# Out:
#            file_name                   bbox  image_id       race     age  \
# 0      100147591.jpg  [1146, 463, 250, 311]         1  Mongoloid  20-30s
# 1      100429351.jpg   [589, 308, 322, 334]         2  Mongoloid  20-30s
# 2      100473997.jpg   [664, 285, 336, 496]         3  Mongoloid  Senior
# 3      100868012.jpg   [995, 228, 123, 195]         4  Mongoloid  20-30s
# 4      101013830.jpg   [838, 462, 304, 380]         5  Mongoloid  Senior
# ...              ...                    ...       ...        ...     ...
# 2169  image_9841.jpg   [269, 179, 608, 786]      2180  Mongoloid  40-50s
# 2170  image_9913.jpg   [248, 162, 561, 824]      2181  Mongoloid  20-30s
# 2171  image_9915.jpg   [205, 173, 573, 799]      2182  Mongoloid  20-30s
# 2172  image_9935.jpg   [275, 163, 581, 781]      2183  Mongoloid  20-30s
# 2173  image_9975.jpg   [199, 158, 574, 768]      2184  Mongoloid  20-30s
#
#         emotion  gender   skintone    masked
# 0       Neutral  Female      light  unmasked
# 1       Neutral    Male      light  unmasked
# 2     Happiness    Male  mid-light  unmasked
# 3     Happiness  Female      light  unmasked
# 4     Happiness    Male      light  unmasked
# ...         ...     ...        ...       ...
# 2169  Happiness    Male      light  unmasked
# 2170  Happiness  Female  mid-light  unmasked
# 2171  Happiness    Male      light  unmasked
# 2172  Happiness  Female      light  unmasked
# 2173  Happiness  Female      light  unmasked
#
# [2174 rows x 9 columns]

# %%
df["race_y"].value_counts()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df["race_y"].value_counts()
#
# NameError: name 'df' is not defined
