# %%
import pandas as pd
import numpy as np

# %%
df_race = pd.read_csv("/media/gnort/HDD6/Study/face-analysis-lightning/dataset/face/image_lists/face_train_added_gender.txt", sep=" ", header=None)
df_race
# Out:
#                                   0  1  2  3  4  5  6
# 0                          9936.jpg  1  0  3  1  4  1
# 1                          4458.jpg  1  0  3  1  3  1
# 2                          2214.jpg  1  1  3  1  3  1
# 3                           202.jpg  0  1  3  1  6  1
# 4                         13680.jpg  0  1  3  1  4  1
# ...                             ... .. .. .. .. .. ..
# 17243  15_0_0_20170117134820249.jpg  0  1  0  0  0  0
# 17244  19_0_2_20170104020121132.jpg  0  1  0  0  0  0
# 17245  58_0_1_20170117192005261.jpg  0  1  0  0  0  0
# 17246  25_0_0_20170116213510820.jpg  0  1  0  0  0  0
# 17247  26_0_1_20170117195949276.jpg  0  1  0  0  0  0
#
# [17248 rows x 7 columns]

# %%
df_race[2].value_counts()
# Out:
# 2
# 1    8839
# 0    8409
# Name: count, dtype: int64

# %%
df = pd.read_csv("/media/gnort/HDD6/Study/face-analysis-lightning/outputs/train.csv", sep=",", header=None)
df
# Out:
#                                        0                                   1  \
# 0                                                                       0  1
# 1                             aligned_faces/aligned_faces/images/5263.jpg  0
# 2                             aligned_faces/aligned_faces/images/4803.jpg  2
# 3      aligned_faces_additional/aligned_faces_additional/images/15964.jpg  2
# 4                             aligned_faces/aligned_faces/images/6041.jpg  3
# ...                                                                   ... ..
# 22434  aligned_faces_additional/aligned_faces_additional/images/27484.jpg  0
# 22435  aligned_faces_additional/aligned_faces_additional/images/16051.jpg  2
# 22436  aligned_faces_additional/aligned_faces_additional/images/25057.jpg  0
# 22437                         aligned_faces/aligned_faces/images/2887.jpg  0
# 22438                         aligned_faces/aligned_faces/images/5216.jpg  3
#
#        2  3  4  5  6
# 0      2  3  4  5  6
# ...

# %%
def cvt_txt_to_csv(txt_file, csv_file):
    df = pd.read_csv(txt_file, sep=" ", header=None)
    df.to_csv(csv_file, index=False)
txt_file = "/media/gnort/HDD6/Downloads_New/Data/face_challenge_dataset/image_lists_full/image_lists_full/train.txt"
cvt_txt_to_csv(txt_file, "/media/gnort/HDD6/Study/face-analysis-lightning/outputs/train.csv")

# %%
from autoviz.AutoViz_Class import AutoViz_Class
AV = AutoViz_Class()

# %matplotlib inline 

# Generate visualizations
AV.AutoViz("/media/gnort/HDD6/Study/face-analysis-lightning/outputs/train.csv",
           sep=",",
           dfte=None,
           header=0,
           verbose=1,
           lowess=False,
           chart_format="svg",
           max_rows_analyzed=150000,
           max_cols_analyzed=30)
# Out:
# Shape of your Data Set loaded: (22438, 7)
# #######################################################################################
# ######################## C L A S S I F Y I N G  V A R I A B L E S  ####################
# #######################################################################################
# Classifying variables in data set...
#     Number of Numeric Columns =  0
#     Number of Integer-Categorical Columns =  4
#     Number of String-Categorical Columns =  0
#     Number of Factor-Categorical Columns =  0
#     Number of String-Boolean Columns =  0
#     Number of Numeric-Boolean Columns =  2
#     Number of Discrete String Columns =  0
#     Number of NLP String Columns =  1
#     Number of Date Time Columns =  0
#     Number of ID Columns =  0
#     Number of Columns to Delete =  0
#     7 Predictors classified...
#         No variables removed since no ID or low-information variables found in data set
# ...

# %%
indices_to_keep_1 = np.random.choice(df[df[1] == 1].index, 3000, replace=False)
indices_to_keep_0 = np.random.choice(df[df[1] == 0].index, 3000, replace=False)
indices_to_keep_2 = df[df[1] == 2].index

# Combine the selected indices for both values
indices_to_keep = np.concatenate([indices_to_keep_1, indices_to_keep_0, indices_to_keep_2])

# Keep only the selected indices and reset the index
df_filtered = df.loc[indices_to_keep].reset_index(drop=True)

# %%
df_filtered

# %%
df_filtered[1].value_counts()

# %%
df_filtered.to_csv("/media/gnort/HDD6/Study/face-analysis-lightning/dataset/face/image_lists/face_train_5_1_race.txt", sep=" ", header=None, index=False)

# %%
def rename_files(image_dir):
    import os
    for root, dirs, files in os.walk(image_dir):
        for file in files:
            if file.endswith(".chip.jpg"):
                os.rename(os.path.join(root, file), os.path.join(root, file.replace(".chip.jpg", "")))
                print("Renamed: ", os.path.join(root, file), " to ", os.path.join(root, file.replace(".chip.jpg", "")))
rename_files("/media/gnort/HDD6/Downloads_New/Compress/UTKface_aligned/UTKFace")

# %%
import os
import random
image_dir = sorted(os.listdir("/media/gnort/HDD6/Downloads_New/Compress/UTKface_aligned/UTKFace"))
race_images = []
for image_name in image_dir:
    if image_name.split("_")[2] == "1" and len(image_name.split(" ")) == 1:
        race_images.append(image_name)
random.seed(31337)
# race_list = random.sample(race_images, 5500)
race_list = race_images
print(len(race_list))

# %%
def create_txt_file(image_list, attr, file_name):
    if os.path.exists(file_name):
        os.remove(file_name)
    s = " 0"
    if attr == "age":
        pos = 0
    elif attr == "gender":
        pos = 1
    elif attr == "race":
        pos = 2
    else:
        raise ValueError("Invalid attribute")
    with open(file_name, "w") as f:
        for image in image_list:
            if (len(image.split(" "))) > 1:
                continue
            attr_value = image.split("_")[pos]
            if pos == 1:
                attr_value = str(int(attr_value) + 1)
                f.write(image + s + " " + attr_value + s * 4 + "\n")
            if pos == 2:
                attr_value = str(int(attr_value) + 1)
                f.write(image + " " + attr_value + s * 5 + "\n")
    print(len(image_list))
            
create_txt_file(race_list,
                "race",
                "/media/gnort/HDD6/Study/face-analysis-lightning/dataset/face/image_lists/added_race.txt")
# Out:
# 4525

# %%
def copy_images(image_list, source_dir, destination_dir):
    for image in image_list:
        os.system("cp " + source_dir + image + " " + destination_dir)
        print("Copied " + image)
        
source_dir = "/media/gnort/HDD6/Downloads_New/Compress/UTKface_aligned/UTKFace/"
destination_dir = "/media/gnort/HDD6/Study/face-analysis-lightning/dataset/face/aligned_faces_added_race/"
image_list = race_list
copy_images(image_list, source_dir, destination_dir)
# Out:
# Copied 105_1_1_20170112213303693.jpg
# Copied 10_0_1_20170104010841239.jpg
# Copied 10_0_1_20170110220507258.jpg
# Copied 10_0_1_20170110220523360.jpg
# Copied 10_0_1_20170110223455893.jpg
# Copied 10_0_1_20170110223848885.jpg
# Copied 10_0_1_20170110225121326.jpg
# Copied 10_0_1_20170110225339066.jpg
# Copied 10_0_1_20170116225209209.jpg
# Copied 10_1_1_20170109202938302.jpg
# Copied 10_1_1_20170109203348828.jpg
# Copied 10_1_1_20170109203520178.jpg
# Copied 10_1_1_20170109203522559.jpg
# Copied 10_1_1_20170109204636561.jpg
# Copied 10_1_1_20170110225155603.jpg
# Copied 10_1_1_20170116225209209.jpg
# Copied 10_1_1_20170117134313205.jpg
# Copied 110_1_1_20170110155201038.jpg
# Copied 115_1_1_20170112213257263.jpg
# Copied 11_0_1_20170103201136230.jpg
# Copied 11_1_1_20170109203712835.jpg
# Copied 11_1_1_20170114033545468.jpg
# Copied 12_0_1_20170110224244673.jpg
# Copied 12_0_1_20170110225335956.jpg
# Copied 12_1_1_20170109204024091.jpg
# Copied 12_1_1_20170109204809866.jpg
# ...

# %%
def merge_two_txt_files(file1, file2, file3):
    if os.path.exists(file3):
        os.remove(file3)
    with open(file1, "r") as f1, open(file2, "r") as f2, open(file3, "w") as f3:
        for line in f1:
            f3.write(line)
        for line in f2:
            f3.write(line)
    print("Merge done!")
file1 = "/media/gnort/HDD6/Study/face-analysis-lightning/dataset/face/image_lists/face_train.txt"
file2 = "/media/gnort/HDD6/Study/face-analysis-lightning/dataset/face/image_lists/added_race.txt"
file3 = "/media/gnort/HDD6/Study/face-analysis-lightning/dataset/face/image_lists/face_train_added_race.txt"
merge_two_txt_files(file1, file2, file3)
# Out:
# Merge done!

# %%
image = cv2.imread("/media/gnort/HDD6/Study/face-analysis-lightning/dataset/face/aligned_faces_added_race/11676.jpg")
                    /media/gnort/HDD6/Study/face-analysis-lightning/dataset/face/aligned_faces_balanced_race/11676.jpg
# Out:
# [ WARN:0@293509.743] global loadsave.cpp:248 findDecoder imread_('/media/gnort/HDD6/Study/face-analysis-lightning/dataset/face/aligned_faces_added_race/11676.jpg'): can't open/read file: check file path/integrity
